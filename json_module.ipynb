# %%
import json

data = {"name": "Alice", "age": 25, "city": "New York"}

json_string = json.dumps(data) #dumps means dump as a string
print(json_string)  # Output: {"name": "Alice", "age": 25, "city": "New York"}
print()
print(type(json_string))  # <class 'str'>
# Out:
# {"name": "Alice", "age": 25, "city": "New York"}
# <class 'str'>

# %%
json_data = '{"name": "Alice", "age": 25, "city": "New York"}'

python_obj = json.loads(json_data)#converts json strings to python objects - dicts
print(python_obj)  # Output: {'name': 'Alice', 'age': 25, 'city': 'New York'}
print(type(python_obj))  # <class 'dict'>
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}
# <class 'dict'>
